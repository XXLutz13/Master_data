# %% [markdown]
# # Ploting the RTP Log files

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.ticker import MultipleLocator
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Latin Modern Roman"],  # must be installed on your system
    "mathtext.fontset": "cm",             # Computer Modern math, matches LaTeX style
    "text.usetex": True                    # render text via LaTeX
})

# %%
file_path = r"K:\tech_stud\Hager_Lutz\NiSi-Stückchen\RTP\2Box_750C_20s_800C_120s_N2_2Vac_noRot.csv"

data = pd.read_csv(file_path, delimiter=';')
print(data.info())
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253371 entries, 0 to 253370
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Timestamp in s                        253371 non-null  float64
#  1   Recipe-Step                           253371 non-null  object
#  2   [20] Ar_20slm_Readout in slm          2413 non-null    float64
#  3   [111] Butterfly Opening in %0         12065 non-null   float64
#  4   [2] Chamber_Pressure_Readout in Torr  12068 non-null   float64
#  5   [102] HeatValue in %                  120654 non-null  float64
#  6   [83] N2_150slm_Readout in slm         2413 non-null    float64
#  7   [22] N2_30slm_Readout in slm          2413 non-null    float64
#  8   [84] O2 Level in pu                   2413 non-null    float64
#  9   [24] O2_20slm_Readout in slm          2413 non-null    float64
#  10  [109] T_Mdl3 in °C                    120649 non-null  float64
#  11  [12] Wafer_Z_Position_Readout in mm   2413 non-null    float64
#  12  Unnamed: 12                           0 non-null       float64
# dtypes: float64(12), object(1)
# memory usage: 25.1+ MB
# None
#         Timestamp in s Recipe-Step  [20] Ar_20slm_Readout in slm  \
# 0                0.498       Purge                           NaN
# 1                0.598       Purge                           NaN
# 2                0.669       Purge                           NaN
# 3                0.679       Purge                           NaN
# 4                0.689       Purge                           NaN
# ...                ...         ...                           ...
# 253366        1207.181         End                           NaN
# 253367        1207.189         End                           NaN
# 253368        1207.191         End                           NaN
# 253369        1207.198         End                           NaN
# 253370        1207.199         End                           NaN
#
#         [111] Butterfly Opening in %0  [2] Chamber_Pressure_Readout in Torr  \
# 0                                 NaN                               714.077
# 1                                 NaN                               715.450
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
# ...                               ...                                   ...
# 253366                            NaN                                   NaN
# 253367                            NaN                                   NaN
# 253368                            NaN                                   NaN
# 253369                         42.146                               727.834
# 253370                            NaN                                   NaN
#
#         [102] HeatValue in %  [83] N2_150slm_Readout in slm  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        0.0                            NaN
# 3                        0.0                            NaN
# 4                        0.0                            NaN
# ...                      ...                            ...
# 253366                   NaN                            NaN
# 253367                   0.0                            NaN
# 253368                   NaN                            NaN
# 253369                   NaN                            NaN
# 253370                   0.0                            NaN
#
#         [22] N2_30slm_Readout in slm  [84] O2 Level in pu  \
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
# ...                              ...                  ...
# 253366                           NaN                  NaN
# 253367                           NaN                  NaN
# 253368                           NaN                  NaN
# 253369                           NaN                  NaN
# 253370                           NaN                  NaN
#
#         [24] O2_20slm_Readout in slm  [109] T_Mdl3 in °C  \
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ...                              ...                 ...
# 253366                           NaN            137.6147
# 253367                           NaN                 NaN
# 253368                           NaN            137.6037
# 253369                           NaN                 NaN
# 253370                           NaN                 NaN
#
#         [12] Wafer_Z_Position_Readout in mm  Unnamed: 12
# 0                                       NaN          NaN
# 1                                       NaN          NaN
# 2                                       NaN          NaN
# 3                                       NaN          NaN
# 4                                       NaN          NaN
# ...                                     ...          ...
# 253366                                  NaN          NaN
# 253367                                  NaN          NaN
# 253368                                  NaN          NaN
# 253369                                  NaN          NaN
# 253370                                  NaN          NaN
#
# [253371 rows x 13 columns]

# %%
plt.figure(figsize=(8, 6))
ax = plt.gca()

plt.plot(data['Timestamp in s'], data['[109] T_Mdl3 in °C'])

plt.tight_layout()
plt.grid(True)
plt.show()
