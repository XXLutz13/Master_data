# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = '../Carlito-Regular.ttf'
fm.fontManager.addfont(font_path) # Register the file with Matplotlib

plt.rcParams['font.family'] = 'Carlito'

# %%
plt.figure(figsize=(8, 5))

plt.xlabel("Voltage / V")
plt.ylabel("Current / mA")
# plt.xlim(-0.5, 0.5)
plt.title(r'Test \Phi_B')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lhager\AppData\Local\Temp\ipykernel_16660\3484477785.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
